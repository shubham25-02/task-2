# %%
my_friend=akshay
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ebca35cd851> in <module>
# ----> 1 my_friend=akshay
#
# NameError: name 'akshay' is not defined

# %%
my_friend
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-70df25fac613> in <module>
# ----> 1 my_friend
#
# NameError: name 'my_friend' is not defined

# %%
my friend="aksay"
# Out:
#   File "<ipython-input-3-8648fed45656>", line 1
#     my friend="aksay"
#        ^
# SyntaxError: invalid syntax

# %%
my_friend=['aksay','aman']

# %%
my_friend
# Out:
# ['aksay', 'aman']

# %%
places=['delhi','chennai','bangalore']

# %%
places
# Out:
# ['delhi', 'chennai', 'bangalore']

# %%
new=my_friend+places

# %%
new
# Out:
# ['aksay', 'aman', 'delhi', 'chennai', 'bangalore']

# %%
new(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-66b0d7aba4c0> in <module>
# ----> 1 new(0)
#
# TypeError: 'list' object is not callable

# %%
new[0]
# Out:
# 'aksay'

# %%
num=8

# %%
num
# Out:
# 8

# %%
num=+19

# %%
num
# Out:
# 19

# %%
num
# Out:
# 19

# %%
num+=19

# %%
num
# Out:
# 38

# %%
num*=2

# %%
num
# Out:
# 76

# %%
type(num)
# Out:
# int

# %%
my_list=[1,2,3,4]

# %%
my_list[2,]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f944202179f9> in <module>
# ----> 1 my_list[2,]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
my_list[2.]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-bc8f2d5dafa2> in <module>
# ----> 1 my_list[2.]
#
# TypeError: list indices must be integers or slices, not float

# %%
my_list[1]
# Out:
# 2

# %%
price=25

# %%
num=4

# %%
total_cost=price*num

# %%
total_cost
# Out:
# 100

# %%
total_cost-=25

# %%
total_cost
# Out:
# 75
